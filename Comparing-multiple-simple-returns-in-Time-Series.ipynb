# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
fb = pd.read_csv("ticker-fb.csv", index_col=0, parse_dates=True)
goog = pd.read_csv("ticker-goog.csv", index_col=0, parse_dates=True)
hp = pd.read_csv("ticker-hp.csv", index_col=0, parse_dates=True)
nvda = pd.read_csv("ticker-nvda.csv", index_col=0, parse_dates=True)

# %%
# concat all the adjusted close of the columns
data = pd.concat([fb['Adj Close'], goog['Adj Close'], hp['Adj Close'], nvda['Adj Close']], axis=1)

# %%
data.columns = ['FB', 'GOOG', 'HP', 'NVDA']

# %%
data.head()
# Out:
#                     FB         GOOG         HP        NVDA
# Date
# 2020-01-02  209.779999  1367.369995  41.416153  239.514771
# 2020-01-03  208.669998  1360.660034  41.946781  235.681122
# 2020-01-06  212.600006  1394.209961  43.136116  236.669479
# 2020-01-07  213.059998  1393.339966  42.578041  239.534729
# 2020-01-08  215.220001  1404.319946  41.699768  239.984009

# %%
fig1, ax1 = plt.subplots()
data.plot(ax = ax1)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: xlabel='Date'>

# %%
# divide each row by the first row to see how much grow in total
data/data.iloc[0]
# Out:
#                   FB      GOOG        HP      NVDA
# Date
# 2020-01-02  1.000000  1.000000  1.000000  1.000000
# 2020-01-03  0.994709  0.995093  1.012812  0.983994
# 2020-01-06  1.013443  1.019629  1.041529  0.988121
# 2020-01-07  1.015635  1.018993  1.028054  1.000083
# 2020-01-08  1.025932  1.027023  1.006848  1.001959
# ...              ...       ...       ...       ...
# 2020-12-24  1.274669  1.271675  0.584313  2.170012
# 2020-12-28  1.320431  1.298910  0.571758  2.154356
# 2020-12-29  1.319382  1.286206  0.567170  2.161579
# 2020-12-30  1.295977  1.272165  0.569343  2.195397
# 2020-12-31  1.302126  1.281204  0.559202  2.180241
#
# [253 rows x 4 columns]

# %%
# percentage change in data from day to day using cumulative product
# multiples all of them down there
(data.pct_change() + 1).cumprod()
# Out:
#                   FB      GOOG        HP      NVDA
# Date
# 2020-01-02       NaN       NaN       NaN       NaN
# 2020-01-03  0.994709  0.995093  1.012812  0.983994
# 2020-01-06  1.013443  1.019629  1.041529  0.988121
# 2020-01-07  1.015635  1.018993  1.028054  1.000083
# 2020-01-08  1.025932  1.027023  1.006848  1.001959
# ...              ...       ...       ...       ...
# 2020-12-24  1.274669  1.271675  0.584313  2.170012
# 2020-12-28  1.320431  1.298910  0.571758  2.154356
# 2020-12-29  1.319382  1.286206  0.567170  2.161579
# 2020-12-30  1.295977  1.272165  0.569343  2.195397
# 2020-12-31  1.302126  1.281204  0.559202  2.180241
#
# [253 rows x 4 columns]

# %%
df = data/data.iloc[0]

# %%
fig2, ax2 = plt.subplots()
df.plot(ax=ax2)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: xlabel='Date'>

# %%
norm = (data/data.iloc[0])*100

# %%
norm.head()
# Out:
#                     FB        GOOG          HP        NVDA
# Date
# 2020-01-02  100.000000  100.000000  100.000000  100.000000
# 2020-01-03   99.470874   99.509280  101.281211   98.399410
# 2020-01-06  101.344269  101.962890  104.152880   98.812060
# 2020-01-07  101.563542  101.899264  102.805398  100.008333
# 2020-01-08  102.593194  102.702264  100.684793  100.195912

# %%
fig3, ax3 = plt.subplots()
df.plot(ax=ax3)
# Out:
# <img src="data:image/png;base64,..." width="640">
# <Axes: xlabel='Date'>
