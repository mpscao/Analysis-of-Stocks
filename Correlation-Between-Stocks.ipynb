# %%
import pandas as pd
import numpy as np

# %%
tickers = ['FB', 'AMZN', 'AAPL', 'HP', 'NVDA']

df_list = []
for ticker in tickers:
    df = pd.read_csv("ticker-" + ticker + ".csv", index_col=0, parse_dates=True)
    df_list.append(df['Adj Close'])

data = pd.concat(df_list, axis=1)
data.columns = tickers

# %%
data.tail()
# Out:
#                     FB         AMZN        AAPL         HP        NVDA
# Date
# 2020-12-24  267.399994  3172.689941  131.970001  24.200001  519.750000
# 2020-12-28  277.000000  3283.959961  136.690002  23.680000  516.000000
# 2020-12-29  276.779999  3322.000000  134.869995  23.490000  517.729980
# 2020-12-30  271.869995  3285.850098  133.720001  23.580000  525.830017
# 2020-12-31  273.160004  3256.929932  132.690002  23.160000  522.200012

# %%
# find the log values for more accurate changes
data = np.log(data/data.shift())

# %%
data.corr()
# Out:
#             FB      AMZN      AAPL        HP      NVDA
# FB    1.000000  0.631197  0.618762  0.300743  0.579946
# AMZN  0.631197  1.000000  0.657111  0.272401  0.637538
# AAPL  0.618762  0.657111  1.000000  0.395108  0.660589
# HP    0.300743  0.272401  0.395108  1.000000  0.365675
# NVDA  0.579946  0.637538  0.660589  0.365675  1.000000

# %%
data.corr().style.background_gradient(cmap = 'Blues')
# Out:
# <style type="text/css">
# #T_e9644_row0_col0, #T_e9644_row1_col1, #T_e9644_row2_col2, #T_e9644_row3_col3, #T_e9644_row4_col4 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e9644_row0_col1 {
#   background-color: #6dafd7;
#   color: #f1f1f1;
# }
# #T_e9644_row0_col2 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_e9644_row0_col3 {
#   background-color: #f0f6fd;
#   color: #000000;
# }
# #T_e9644_row0_col4 {
#   background-color: #aacfe5;
#   color: #000000;
# }
# #T_e9644_row1_col0 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_e9644_row1_col2 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_e9644_row1_col3, #T_e9644_row3_col0, #T_e9644_row3_col1, #T_e9644_row3_col2, #T_e9644_row3_col4 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e9644_row1_col4 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_e9644_row2_col0 {
#   background-color: #7db8da;
#   color: #000000;
# }
# #T_e9644_row2_col1 {
#   background-color: #61a7d2;
#   color: #f1f1f1;
# }
# #T_e9644_row2_col3 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_e9644_row2_col4 {
#   background-color: #79b5d9;
#   color: #000000;
# }
# #T_e9644_row4_col0 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_e9644_row4_col1 {
#   background-color: #6aaed6;
#   color: #f1f1f1;
# }
# #T_e9644_row4_col2 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_e9644_row4_col3 {
#   background-color: #deebf7;
#   color: #000000;
# }
# </style>
# <table id="T_e9644">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e9644_level0_col0" class="col_heading level0 col0" >FB</th>
#       <th id="T_e9644_level0_col1" class="col_heading level0 col1" >AMZN</th>
#       <th id="T_e9644_level0_col2" class="col_heading level0 col2" >AAPL</th>
#       <th id="T_e9644_level0_col3" class="col_heading level0 col3" >HP</th>
#       <th id="T_e9644_level0_col4" class="col_heading level0 col4" >NVDA</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9644_level0_row0" class="row_heading level0 row0" >FB</th>
#       <td id="T_e9644_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e9644_row0_col1" class="data row0 col1" >0.631197</td>
#       <td id="T_e9644_row0_col2" class="data row0 col2" >0.618762</td>
#       <td id="T_e9644_row0_col3" class="data row0 col3" >0.300743</td>
#       <td id="T_e9644_row0_col4" class="data row0 col4" >0.579946</td>
#     </tr>
#     <tr>
#       <th id="T_e9644_level0_row1" class="row_heading level0 row1" >AMZN</th>
#       <td id="T_e9644_row1_col0" class="data row1 col0" >0.631197</td>
#       <td id="T_e9644_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e9644_row1_col2" class="data row1 col2" >0.657111</td>
#       <td id="T_e9644_row1_col3" class="data row1 col3" >0.272401</td>
#       <td id="T_e9644_row1_col4" class="data row1 col4" >0.637538</td>
#     </tr>
#     <tr>
#       <th id="T_e9644_level0_row2" class="row_heading level0 row2" >AAPL</th>
#       <td id="T_e9644_row2_col0" class="data row2 col0" >0.618762</td>
#       <td id="T_e9644_row2_col1" class="data row2 col1" >0.657111</td>
#       <td id="T_e9644_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e9644_row2_col3" class="data row2 col3" >0.395108</td>
#       <td id="T_e9644_row2_col4" class="data row2 col4" >0.660589</td>
#     </tr>
#     <tr>
#       <th id="T_e9644_level0_row3" class="row_heading level0 row3" >HP</th>
#       <td id="T_e9644_row3_col0" class="data row3 col0" >0.300743</td>
#       <td id="T_e9644_row3_col1" class="data row3 col1" >0.272401</td>
#       <td id="T_e9644_row3_col2" class="data row3 col2" >0.395108</td>
#       <td id="T_e9644_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e9644_row3_col4" class="data row3 col4" >0.365675</td>
#     </tr>
#     <tr>
#       <th id="T_e9644_level0_row4" class="row_heading level0 row4" >NVDA</th>
#       <td id="T_e9644_row4_col0" class="data row4 col0" >0.579946</td>
#       <td id="T_e9644_row4_col1" class="data row4 col1" >0.637538</td>
#       <td id="T_e9644_row4_col2" class="data row4 col2" >0.660589</td>
#       <td id="T_e9644_row4_col3" class="data row4 col3" >0.365675</td>
#       <td id="T_e9644_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>
